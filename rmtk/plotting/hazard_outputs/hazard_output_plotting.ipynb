# %% [markdown]
# # Visualise the Hazard Outputs of a Calculation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from plot_hazard_outputs import HazardCurve, UniformHazardSpectra, HazardMap

# %% [markdown]
# ### Hazard Curve

# %%
hazard_curve_file = "../sample_outputs/hazard/hazard_curves.xml"
hazard_curves = HazardCurve(hazard_curve_file)

# %%
hazard_curves.loc_list
# Out:
# ['80.088823|28.861172',
#  '80.088823|28.936172',
#  '80.129167|29.037500',
#  '80.163823|28.786172',
#  '80.163823|28.861172',
#  '80.163823|28.936172',
#  '80.163823|29.011172',
#  '80.238823|28.786172',
#  '80.238823|28.861172',
#  '80.238823|28.936172',
#  '80.238823|29.011172',
#  '80.238823|29.086172',
#  '80.313823|28.711172',
#  '80.313823|28.786172',
#  '80.313823|28.861172',
#  '80.313823|29.011172',
#  '80.313823|29.086172',
#  '80.313823|29.161172',
#  '80.313823|29.236172',
#  '80.313823|29.311172',
#  '80.313823|29.386172',
#  '80.313823|29.461172',
#  '80.354167|28.887500',
#  '80.388823|28.636172',
#  '80.388823|28.711172',
#  '80.388823|28.786172',
#  '80.388823|28.861172',
#  '80.388823|28.936172',
#  '80.388823|29.011172',
#  '80.388823|29.086172',
#  '80.388823|29.161172',
#  '80.388823|29.236172',
#  '80.388823|29.311172',
#  '80.388823|29.386172',
#  '80.388823|29.461172',
#  '80.388823|29.536172',
#  '80.388823|29.686172',
#  '80.463823|28.636172',
# ...

# %%
hazard_curves.plot("81.213823|29.761172")

# %% [markdown]
# ## Uniform Hazard Spectra

# %%
uhs_file = "../sample_outputs/hazard/uniform_hazard_spectra.xml"
uhs = UniformHazardSpectra(uhs_file)

# %%
uhs.plot(0)

# %% [markdown]
# ## Hazard Map

# %%
haz_map = HazardMap("../sample_outputs/hazard/hazard_map.xml")

# %%
box = {"lon_1": 80.088823, "lat_1": 26.386172, "lon_2": 88.113823, "lat_2": 30.361172, "lat_length":2.0, "lon_length":5.0}
haz_map.plot(box, "Hazard Map Nepal", 1, log_scale=False)
