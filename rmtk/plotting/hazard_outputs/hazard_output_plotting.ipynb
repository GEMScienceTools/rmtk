# %% [markdown]
# # Visualise the Hazard Outputs of a Calculation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from plot_hazard_outputs import HazardCurve, UniformHazardSpectra, HazardMap

# %% [markdown]
# ### Hazard Curve

# %%
hazard_curve_file = "data/hazard_curves_short.xml"
hazard_curves = HazardCurve(hazard_curve_file)

# %%
hazard_curves.loc_list
# Out:
# ['-122.874442|42.029656',
#  '-122.753370|42.029656',
#  '-122.632298|42.029656',
#  '-122.511226|42.029656',
#  '-122.390154|42.029656',
#  '-122.269082|42.029656',
#  '-124.327648|41.939724',
#  '-124.206747|41.939724',
#  '-124.085846|41.939724',
#  '-123.964944|41.939724',
#  '-123.844043|41.939724',
#  '-123.723142|41.939724',
#  '-123.602241|41.939724',
#  '-123.481340|41.939724']

# %%
hazard_curves.plot("-122.874442|42.029656")

# %% [markdown]
# ## Uniform Hazard Spectra

# %%
uhs_file = "data/uniform_hazard_spectra_short.xml"
uhs = UniformHazardSpectra(uhs_file)

# %%
uhs.plot(0)

# %% [markdown]
# ## Hazard Map

# %%
haz_map = HazardMap("data/hazard_map.xml")

# %%
box = {"lon_1": -125., "lat_1": 32., "lon_2": -114., "lat_2": 42.5, "lat_length":2.0, "lon_length":5.0}
haz_map.plot(box, "Hazard Map California", 1, log_scale=True)
